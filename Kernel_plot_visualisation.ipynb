# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

file_path = r"C:\Users\adrib\Downloads\Tier_List_Smash – V2.xlsx"
# Read the Excel file with a single column and split it based on commas
data = pd.read_excel(file_path, header=None, names=['Data'])
data[['Name', 'Rank', 'License', 'Weight', 'Gravity', 'Run_speed', 'FOOS', 'Gameplay','Release_opus','Special_mechanic','Air_speed']] = data['Data'].str.split(',', expand=True)

# Convert numerical columns to numeric type
numeric_columns = ['Weight', 'Gravity', 'Run_speed', 'FOOS','Release_opus','Air_speed']
data[numeric_columns] = data[numeric_columns].apply(pd.to_numeric, errors='coerce')

# Define the custom order for Rang_tierlist
custom_order = ['S+', 'S', 'S-', 'A+', 'A', 'A-', 'B+', 'B', 'B-', 'C+', 'C', 'C-', 'D+', 'D-', 'E']

# Set the style for the plots (optional)
sns.set(style="whitegrid")

feature_list = ["Weight","Gravity","Run_speed","Release_opus","Special_mechanic","Gameplay","FOOS","License","Air_speed"]

for feature in feature_list:

    if (feature == "Special_mechanic"):
        plt.figure(figsize=(3,2))
    else:
        # Create a figure and axis
        plt.figure(figsize=(12, 8))

    # Use seaborn's catplot to generate categorical scatter plots for each tier
    sns.catplot(x="Rank", y=feature, data=data, kind="swarm", order=custom_order, palette="viridis")

    # Set plot labels and title
    plt.xlabel("Rank")
    plt.ylabel(feature)
    plt.title("Categorical Scatter Plot of "+feature+" for Each Rank")

    # Show the plot
    plt.show()
# Out:
# C:\Users\adrib\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 12.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\adrib\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 9.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\adrib\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 18.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\adrib\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 11.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

file_path = r"C:\Users\adrib\Downloads\Tier_List_Smash – V2.xlsx"
# Read the Excel file with a single column and split it based on commas
data = pd.read_excel(file_path, header=None, names=['Data'])
data[['Name', 'Rank', 'License', 'Weight', 'Gravity', 'Run_speed', 'FOOS', 'Gameplay','Release_opus','Special_mechanic','Air_speed']] = data['Data'].str.split(',', expand=True)

# Convert numerical columns to numeric type
numeric_columns = ['Weight', 'Gravity', 'Run_speed', 'FOOS','Release_opus','Special_mechanic','Air_speed']
data[numeric_columns] = data[numeric_columns].apply(pd.to_numeric, errors='coerce')

# Define the custom order for Rang_tierlist
custom_order = ['S+', 'S', 'S-', 'A+', 'A', 'A-', 'B+', 'B', 'B-', 'C+', 'C', 'C-', 'D+', 'D-', 'E']

# Set the style for the plots (optional)
sns.set(style="whitegrid")

list_feature1 = ["Air_speed"]

list_feature2 = ["Run_speed"]

list_feature3 = ["Gravity"]

for feature1 in list_feature1:
    
    for feature2 in list_feature2:

        # Create a pair plot
        pair_plot = sns.pairplot(data, hue="Rank", palette="viridis", vars=[feature1, feature2])

        # Set plot title
        pair_plot.fig.suptitle("Pair Plot of "+feature1+" and "+feature2+" with Rank")

        # Show the plot
        plt.show()
