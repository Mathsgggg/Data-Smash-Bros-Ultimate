# %%
pip install selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import time
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
path = r"C:\Users\adrib\Documents\DE_MAILLY_NESLE_Adrien_Ecole_UVic\Scrapping"
DRIVER_PATH = path+"\\chromedriver.exe"
liste_perso = ['''//*[@id="charList"]/div[2]/a''',
                '''//*[@id="charList"]/div[3]/a''',
                '''//*[@id="charList"]/div[4]/a''',
                '''//*[@id="charList"]/div[5]/a''',
                '''//*[@id="charList"]/div[6]/a''',
                '''//*[@id="charList"]/div[7]/a''',
                '''//*[@id="charList"]/div[8]/a''',
                '''//*[@id="charList"]/div[9]/a''',
                '''//*[@id="charList"]/div[10]/a''',
                '''//*[@id="charList"]/div[11]/a''',
                '''//*[@id="charList"]/div[12]/a''',
                '''//*[@id="charList"]/div[13]/a''',
                '''//*[@id="charList"]/div[14]/a''',
                '''//*[@id="charList"]/div[15]/a''',
                '''//*[@id="charList"]/div[16]/a''',
                '''//*[@id="charList"]/div[17]/a''',
                '''//*[@id="charList"]/div[18]/a''',
                '''//*[@id="charList"]/div[19]/a''',
                '''//*[@id="charList"]/div[20]/a''',
                '''//*[@id="charList"]/div[21]/a''',
                '''//*[@id="charList"]/div[22]/a''',
                '''//*[@id="charList"]/div[23]/a''',
                '''//*[@id="charList"]/div[24]/a''',
                '''//*[@id="charList"]/div[25]/a''',
                '''//*[@id="charList"]/div[26]/a''',
                '''//*[@id="charList"]/div[27]/a''',
                '''//*[@id="charList"]/div[28]/a''',
                '''//*[@id="charList"]/div[29]/a''',
                '''//*[@id="charList"]/div[30]/a''',
                '''//*[@id="charList"]/div[31]/a''',
                '''//*[@id="charList"]/div[32]/a''',
                '''//*[@id="charList"]/div[33]/a''',
                '''//*[@id="charList"]/div[34]/a''',
                '''//*[@id="charList"]/div[35]/a''',
                '''//*[@id="charList"]/div[36]/a''',
                '''//*[@id="charList"]/div[37]/a''',
                '''//*[@id="charList"]/div[38]/a''',
                '''//*[@id="charList"]/div[39]/a''',
                '''//*[@id="charList"]/div[40]/a''',
                '''//*[@id="charList"]/div[41]/a''',
                '''//*[@id="charList"]/div[42]/a''',
                '''//*[@id="charList"]/div[43]/a''',
                '''//*[@id="charList"]/div[44]/a''',
                '''//*[@id="charList"]/div[45]/a''',
                '''//*[@id="charList"]/div[46]/a''',
                '''//*[@id="charList"]/div[47]/a''',
                '''//*[@id="charList"]/div[48]/a''',
                '''//*[@id="charList"]/div[49]/a''',
                '''//*[@id="charList"]/div[50]/a''',
                '''//*[@id="charList"]/div[51]/a''',
                '''//*[@id="charList"]/div[52]/a''',
                '''//*[@id="charList"]/div[53]/a''',
                '''//*[@id="charList"]/div[54]/a''',
                '''//*[@id="charList"]/div[55]/a''',
                '''//*[@id="charList"]/div[56]/a''',
                '''//*[@id="charList"]/div[57]/a''',
                '''//*[@id="charList"]/div[58]/a''',
                '''//*[@id="charList"]/div[59]/a''',
                '''//*[@id="charList"]/div[60]/a''',
                '''//*[@id="charList"]/div[61]/a''',
                '''//*[@id="charList"]/div[62]/a''',
                '''//*[@id="charList"]/div[63]/a''',
                '''//*[@id="charList"]/div[64]/a''',
                '''//*[@id="charList"]/div[65]/a''',
                '''//*[@id="charList"]/div[66]/a''',
                '''//*[@id="charList"]/div[67]/a''',
                '''//*[@id="charList"]/div[68]/a''',
                '''//*[@id="charList"]/div[69]/a''',
                '''//*[@id="charList"]/div[70]/a''',
                '''//*[@id="charList"]/div[71]/a''',
                '''//*[@id="charList"]/div[72]/a''',
                '''//*[@id="charList"]/div[73]/a''',
                '''//*[@id="charList"]/div[74]/a''',
                '''//*[@id="charList"]/div[75]/a''',
                '''//*[@id="charList"]/div[76]/a''',
                '''//*[@id="charList"]/div[77]/a''',
                '''//*[@id="charList"]/div[78]/a''',
                '''//*[@id="charList"]/div[79]/a''',
                '''//*[@id="charList"]/div[80]/a''',
                '''//*[@id="charList"]/div[81]/a''',
                '''//*[@id="charList"]/div[82]/a''',
                '''//*[@id="charList"]/div[83]/a''',
                '''//*[@id="charList"]/div[84]/a''',
                '''//*[@id="charList"]/div[85]/a''',
                '''//*[@id="charList"]/div[86]/a''',
                '''//*[@id="charList"]/div[87]/a''',
                '''//*[@id="charList"]/div[88]/a''',
                '''//*[@id="charList"]/div[89]/a''',
                '''//*[@id="charList"]/div[90]/a''']


for perso in liste_perso:
    service = Service(executable_path=DRIVER_PATH)
    driver = webdriver.Chrome(service=service)
    driver.get("https://ultimateframedata.com/smash")
    driver.find_element(By.XPATH,perso).click()
    time.sleep(1)

    name = driver.find_element(By.XPATH,'''/html/body/h1''').text
    weight = driver.find_element(By.XPATH,'''//*[@id="contentcontainer"]/div[6]/div[1]/div[2]''').text.split("—")[1]
    gravity = driver.find_element(By.XPATH,'''//*[@id="contentcontainer"]/div[6]/div[1]/div[3]''').text.split("—")[1]
    run_speed = driver.find_element(By.XPATH,'''//*[@id="contentcontainer"]/div[6]/div[1]/div[5]''').text.split("—")[1]
    foos = driver.find_element(By.XPATH,'''//*[@id="contentcontainer"]/div[6]/div[1]/div[11]''').text.split("—")[1].split(" ")[1]
    
    #upsmash_startup = driver.find_element(By.XPATH,'''//*[@id="contentcontainer"]/div[1]/div[11]/div[3]''').text
    #upsmash_active = driver.find_element(By.XPATH,'''//*[@id="contentcontainer"]/div[1]/div[11]/div[12]''').text
    #upsmash_endlag = driver.find_element(By.XPATH,'''//*[@id="contentcontainer"]/div[1]/div[11]/div[13]''').text
    #upsmash_onshield = driver.find_element(By.XPATH,'''//*[@id="contentcontainer"]/div[1]/div[11]/div[11]''').text

    information = name +","+ weight +","+ gravity +","+ run_speed +","+ foos
    #+";"+ upsmash_startup +";"+ upsmash_active +";"+ upsmash_endlag +";"+ upsmash_onshield

    #print(information.split(','))
    print(information)
# Out:
# Banjo & Kazooie, 106, 0.11, 2.18,9
# Terry, 108, 0.09, 1.72,7
# Toon Link, 91, 0.081, 1.906,6
# Villager, 92, 0.078, 1.397,6
# Wario, 107, 0.107, 1.65,6
# Wii Fit Trainer, 96, 0.090, 1.866,6
# Wolf, 92, 0.130, 1.54,9
# Yoshi, 104, 0.080, 2.046,6
# Young Link, 88, 0.096, 1.749,7
# Zelda, 85, 0.071, 1.43,6
# Zero Suit Samus, 80, 0.120, 2.31,6
